# %%
# imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
y
# Out:
# date
# 2000-01-01    nonevent
# 2000-01-20    nonevent
# 2000-01-23    nonevent
# 2000-02-17    nonevent
# 2000-03-25          Ib
#                 ...
# 2009-08-07    nonevent
# 2009-08-24          II
# 2009-08-26    nonevent
# 2009-09-09          II
# 2009-09-13    nonevent
# Name: class4, Length: 360, dtype: category
# Categories (4, object): ['II', 'Ia', 'Ib', 'nonevent']

# %%
# import and modify data
npf_train = pd.read_csv("npf_train.csv")
npf_train = npf_train.drop("partlybad",axis=1)

npf_train = npf_train.set_index("date")
## Tell that "class4" is categorical variable. (R does this automatically.)
npf_train["class4"] = npf_train["class4"].astype("category")

## Here date column was converted to index and we do not need to get rid of it.
npf_train = npf_train.drop("id",axis=1)

## If you don't use dtype="object" array will cut strings...
class2 = np.array(["event"]*npf_train.shape[0],dtype="object")
class2[npf_train["class4"]=="nonevent"] = "nonevent"
npf_train["class2"] = class2
npf_train["class2"] = npf_train["class2"].astype("category")


# reformating X to numerics
for i in range(1,101): # 101 because we have 102 columns
    npf_train.iloc[:,i] = pd.to_numeric(list(npf_train.iloc[:,i]))

## REDUCING the set to get a training and a test set (360 ~ 80% of 458)
X = npf_train.iloc[:360, 1:-1]
y = npf_train.iloc[:360, 0]

# our test set:
X_test = npf_train.iloc[360:, 1:-1]
y_test = npf_train.iloc[360:, 0]

# %%
# train logistic regression model (a basic one for reference)
from sklearn.linear_model import LogisticRegression

model_lr = LogisticRegression()
t_model_lr = model_lr.fit(X, y)

# %%
# computing the score
score_lr = t_model_lr.score(X_test, y_test)
score_lr
# Out:
# 0.8061224489795918

# %%
# retrain with higher max_iter & computing score
model_lr_higher_maxiter = LogisticRegression(max_iter= 10000)
t_model_lr_higher_maxiter = model_lr_higher_maxiter.fit(X,y)
t_model_lr_higher_maxiter_score = t_model_lr_higher_maxiter.score(X_test, y_test) 
t_model_lr_higher_maxiter_score
# Out:
# 0.7244897959183674

# %%
# creating a function outputting the results of the model
def pred_proba_class(t_model, X_test_data, y_test_data): # t_model is the trained model
    df = pd.DataFrame()
    df["X"] = [X_test_data.iloc[i, :] for i in range(len(X_test_data))]
    df["y_true"] = np.array(y_test_data)
    df["y_pred_class"] = t_model.predict(X_test_data)
    proba_event= t_model.predict_proba(X_test_data)[:,0]
    df["y_pred_proba"] = proba_event
    df["correct?"] = [df.iloc[i,1] == df.iloc[i,2] for i in range(len(df))]
    
    return df

pred_proba_class(t_model_lr_higher_maxiter, X_test, y_test)
# Out:
#                                                     X    y_true y_pred_class  \
# 0   CO2168.mean    375.647561
# CO2168.std       3.2...        II           II
# 1   CO2168.mean    382.823235
# CO2168.std       3.8...        II           II
# 2   CO2168.mean    384.067500
# CO2168.std       2.5...        Ib           Ia
# 3   CO2168.mean    384.472708
# CO2168.std       1.9...        II           Ib
# 4   CO2168.mean    390.631489
# CO2168.std       0.8...  nonevent     nonevent
# ..                                                ...       ...          ...
# 93  CO2168.mean    377.541538
# CO2168.std       6.3...  nonevent     nonevent
# 94  CO2168.mean    381.016623
# CO2168.std       4.4...  nonevent     nonevent
# 95  CO2168.mean    386.687895
# CO2168.std      12.0...  nonevent     nonevent
# 96  CO2168.mean    379.279128
# CO2168.std      12.0...  nonevent     nonevent
# 97  CO2168.mean    384.443758
# CO2168.std       6.4...  nonevent     nonevent
#
#     y_pred_proba  correct?
# 0       0.667629      True
# 1       0.580668      True
# 2       0.122637     False
# 3       0.149901     False
# 4       0.028781      True
# ..           ...       ...
# 93      0.161142      True
# 94      0.000126      True
# 95      0.001029      True
# 96      0.006024      True
# 97      0.001548      True
#
# [98 rows x 5 columns]

# %%
# modifying the logistic regression trying to improve the score:

# cross validation for evaluation 




###### predictor selection
# lbfgs and liblinear are not to be used since we want to be able to extend our model to class4 prediction

# Ridge Regression = penalty l2 --> default
model_lr_rr_newton = LogisticRegression(penalty = "l2", solver = 'newton-cg')
t_model_lr_rr_newton = model_lr_rr_newton.fit(X,y)
score_lr_rr_newton = t_model_lr_rr_newton.score(X_test, y_test)

model_lr_rr_sag = LogisticRegression(penalty = "l2", solver = 'sag')
t_model_lr_rr_sag = model_lr_rr_sag.fit(X,y)
score_lr_rr_sag = t_model_lr_rr_sag.score(X_test, y_test)

model_lr_rr_saga = LogisticRegression(penalty = "l2", solver = 'saga')
t_model_lr_rr_saga = model_lr_rr_saga.fit(X,y)
score_lr_rr_saga = t_model_lr_rr_saga.score(X_test, y_test)

# Lasso = penalty l1 
model_lr_lasso = LogisticRegression(penalty = "l1", solver = 'saga')# this solver bc it is the only option for multiclass & l1
t_model_lr_lasso = model_lr_lasso.fit(X,y)
score_lr_lasso = t_model_lr_lasso.score(X_test, y_test)

# none= penalty none
model_lr_none_newton = LogisticRegression(penalty = "none", solver = 'newton-cg')
t_model_lr_none_newton = model_lr_none_newton.fit(X,y)
score_lr_none_newton = t_model_lr_none_newton.score(X_test, y_test)

model_lr_none_sag = LogisticRegression(penalty = "none", solver = 'sag')
t_model_lr_none_sag = model_lr_none_sag.fit(X,y)
score_lr_none_sag = t_model_lr_none_sag.score(X_test, y_test)

model_lr_none_saga = LogisticRegression(penalty = "none", solver = 'saga')
t_model_lr_none_saga = model_lr_none_saga.fit(X,y)
score_lr_none_saga = t_model_lr_none_saga.score(X_test, y_test)

# Lasso + Ridge = ??? = penalty elasticnet
model_lr_elastic = LogisticRegression(penalty = "elasticnet", solver = 'saga', l1_ratio = 0.5) # this solver bc it's the only option, l1_ratio just in the middle for now
t_model_lr_elastic = model_lr_elastic.fit(X,y)
score_lr_elastic = t_model_lr_elastic.score(X_test, y_test)


# parameter tuning



# df for modifications, t_mode and score
mms = pd.DataFrame()
mms["modifications"] = ['RR newton', 'RR sag', 'RR saga', 'Lasso saga', 'none newton', 'none sag', 'none saga', 'Lasso+RR saga']
mms["t_models"] = [t_model_lr_rr_newton, t_model_lr_rr_sag, t_model_lr_rr_saga, t_model_lr_lasso, t_model_lr_none_newton, t_model_lr_none_sag, t_model_lr_none_saga, t_model_lr_elastic]
mms["simple scores"] = [score_lr_rr_newton, score_lr_rr_sag, score_lr_rr_saga, score_lr_lasso, score_lr_none_newton, score_lr_none_sag, score_lr_none_saga, score_lr_elastic]
mms
# Out:
#    modifications                                           t_models  \
# 0      RR newton             LogisticRegression(solver='newton-cg')
# 1         RR sag                   LogisticRegression(solver='sag')
# 2        RR saga                  LogisticRegression(solver='saga')
# 3     Lasso saga    LogisticRegression(penalty='l1', solver='saga')
# 4    none newton  LogisticRegression(penalty='none', solver='new...
# 5       none sag   LogisticRegression(penalty='none', solver='sag')
# 6      none saga  LogisticRegression(penalty='none', solver='saga')
# 7  Lasso+RR saga  LogisticRegression(l1_ratio=0.5, penalty='elas...
#
#    simple scores
# 0       0.724490
# 1       0.775510
# 2       0.785714
# 3       0.785714
# 4       0.632653
# 5       0.775510
# 6       0.785714
# 7       0.785714

# %%
# same thing with maxiter = 1000 --> since there was a worning ...  to see if we get an improvement
# tried with max_iter = 1000 and = 10000 (gave warnings but terminated)
# --> results with 1000 ha better highest value thus here chosen:

# Ridge Regression = penalty l2 --> default
model_lr_rr_newton = LogisticRegression(penalty = "l2", solver = 'newton-cg', max_iter = 1000)
t_model_lr_rr_newton = model_lr_rr_newton.fit(X,y)
score_lr_rr_newton = t_model_lr_rr_newton.score(X_test, y_test)

model_lr_rr_sag = LogisticRegression(penalty = "l2", solver = 'sag',  max_iter = 1000)
t_model_lr_rr_sag = model_lr_rr_sag.fit(X,y)
score_lr_rr_sag = t_model_lr_rr_sag.score(X_test, y_test)

model_lr_rr_saga = LogisticRegression(penalty = "l2", solver = 'saga',  max_iter = 1000)
t_model_lr_rr_saga = model_lr_rr_saga.fit(X,y)
score_lr_rr_saga = t_model_lr_rr_saga.score(X_test, y_test)

# Lasso = penalty l1 
model_lr_lasso = LogisticRegression(penalty = "l1", solver = 'saga',  max_iter = 1000)# this solver bc it is the only option for multiclass & l1
t_model_lr_lasso = model_lr_lasso.fit(X,y)
score_lr_lasso = t_model_lr_lasso.score(X_test, y_test)

# none= penalty none
model_lr_none_newton = LogisticRegression(penalty = "none", solver = 'newton-cg',  max_iter = 1000)
t_model_lr_none_newton = model_lr_none_newton.fit(X,y)
score_lr_none_newton = t_model_lr_none_newton.score(X_test, y_test)

model_lr_none_sag = LogisticRegression(penalty = "none", solver = 'sag',  max_iter = 1000)
t_model_lr_none_sag = model_lr_none_sag.fit(X,y)
score_lr_none_sag = t_model_lr_none_sag.score(X_test, y_test)

model_lr_none_saga = LogisticRegression(penalty = "none", solver = 'saga',  max_iter = 1000)
t_model_lr_none_saga = model_lr_none_saga.fit(X,y)
score_lr_none_saga = t_model_lr_none_saga.score(X_test, y_test)

# Lasso + Ridge = ??? = penalty elasticnet
model_lr_elastic = LogisticRegression(penalty = "elasticnet", solver = 'saga', l1_ratio = 0.5,  max_iter = 1000) # this solver bc it's the only option, l1_ratio just in the middle for now
t_model_lr_elastic = model_lr_elastic.fit(X,y)
score_lr_elastic = t_model_lr_elastic.score(X_test, y_test)


# further parameter tuning possible



# df for modifications, t_mode and score
mmsMI = pd.DataFrame()
mmsMI["modifications"] = ['RR newton', 'RR sag', 'RR saga', 'Lasso saga', 'none newton', 'none sag', 'none saga', 'Lasso+RR saga']
mmsMI["t_models"] = [t_model_lr_rr_newton, t_model_lr_rr_sag, t_model_lr_rr_saga, t_model_lr_lasso, t_model_lr_none_newton, t_model_lr_none_sag, t_model_lr_none_saga, t_model_lr_elastic]
mmsMI["simple scores"] = [score_lr_rr_newton, score_lr_rr_sag, score_lr_rr_saga, score_lr_lasso, score_lr_none_newton, score_lr_none_sag, score_lr_none_saga, score_lr_elastic]
mmsMI
# Out:
#    modifications                                           t_models  \
# 0      RR newton  LogisticRegression(max_iter=1000, solver='newt...
# 1         RR sag    LogisticRegression(max_iter=1000, solver='sag')
# 2        RR saga   LogisticRegression(max_iter=1000, solver='saga')
# 3     Lasso saga  LogisticRegression(max_iter=1000, penalty='l1'...
# 4    none newton  LogisticRegression(max_iter=1000, penalty='non...
# 5       none sag  LogisticRegression(max_iter=1000, penalty='non...
# 6      none saga  LogisticRegression(max_iter=1000, penalty='non...
# 7  Lasso+RR saga  LogisticRegression(l1_ratio=0.5, max_iter=1000...
#
#    simple scores
# 0       0.724490
# 1       0.795918
# 2       0.806122
# 3       0.806122
# 4       0.581633
# 5       0.795918
# 6       0.806122
# 7       0.806122

# %%
# training the upper models using cross validation
import warnings
warnings.filterwarnings('ignore')
warnings.simplefilter('ignore')

from sklearn.model_selection import cross_val_score

cv10 = []
cv50 = []

for model in mms["t_models"]:
    cv = cross_val_score(model, X,y, cv = 10)
    cv10.append(cv)
    cv = cross_val_score(model, X,y, cv = 50)
    cv50.append(cv)
    
mms["cv score 10 fold"] = cv10
mms["cv score 50 fold"] = cv50

# %%
mms
# Out:
#    modifications                                           t_models  \
# 0      RR newton             LogisticRegression(solver='newton-cg')
# 1         RR sag                   LogisticRegression(solver='sag')
# 2        RR saga                  LogisticRegression(solver='saga')
# 3     Lasso saga    LogisticRegression(penalty='l1', solver='saga')
# 4    none newton  LogisticRegression(penalty='none', solver='new...
# 5       none sag   LogisticRegression(penalty='none', solver='sag')
# 6      none saga  LogisticRegression(penalty='none', solver='saga')
# 7  Lasso+RR saga  LogisticRegression(l1_ratio=0.5, penalty='elas...
#
#    simple scores                                   cv score 10 fold  \
# 0       0.724490  [0.5277777777777778, 0.6111111111111112, 0.416...
# 1       0.775510  [0.5833333333333334, 0.6388888888888888, 0.444...
# 2       0.785714  [0.6111111111111112, 0.6666666666666666, 0.472...
# 3       0.785714  [0.6111111111111112, 0.6666666666666666, 0.472...
# 4       0.632653  [0.5, 0.6111111111111112, 0.3888888888888889, ...
# 5       0.775510  [0.5833333333333334, 0.6666666666666666, 0.444...
# 6       0.785714  [0.6111111111111112, 0.6666666666666666, 0.472...
# 7       0.785714  [0.6111111111111112, 0.6666666666666666, 0.472...
#
#                                     cv score 50 fold
# 0  [0.375, 0.375, 0.625, 0.5, 0.75, 0.375, 0.625,...
# 1  [0.625, 0.75, 0.625, 0.375, 0.75, 0.75, 0.5, 0...
# 2  [0.625, 0.75, 0.625, 0.375, 0.75, 0.75, 0.625,...
# 3  [0.625, 0.75, 0.625, 0.375, 0.75, 0.75, 0.625,...
# 4  [0.5, 0.375, 0.625, 0.75, 0.625, 0.625, 0.625,...
# 5  [0.625, 0.75, 0.625, 0.375, 0.75, 0.75, 0.5, 0...
# 6  [0.625, 0.75, 0.625, 0.375, 0.75, 0.75, 0.625,...
# 7  [0.625, 0.75, 0.625, 0.375, 0.75, 0.75, 0.625,...

# %%
# mean cv scores:
cvmean_score = []

for i in range(len(mms)):
    cvmeans = sum(mms.iloc[i,3]) / len(mms.iloc[i,3])
    cvmean_score.append(cvmeans)
    
mms["cv mean score 10"] = cvmean_score


cvmean_score = []

for i in range(len(mms)):
    cvmeans = sum(mms.iloc[i,4]) / len(mms.iloc[i,4])
    cvmean_score.append(cvmeans)
    
mms["cv mean score 50"] = cvmean_score

mms
# Out:
#    modifications                                           t_models  \
# 0      RR newton             LogisticRegression(solver='newton-cg')
# 1         RR sag                   LogisticRegression(solver='sag')
# 2        RR saga                  LogisticRegression(solver='saga')
# 3     Lasso saga    LogisticRegression(penalty='l1', solver='saga')
# 4    none newton  LogisticRegression(penalty='none', solver='new...
# 5       none sag   LogisticRegression(penalty='none', solver='sag')
# 6      none saga  LogisticRegression(penalty='none', solver='saga')
# 7  Lasso+RR saga  LogisticRegression(l1_ratio=0.5, penalty='elas...
#
#    simple scores                                   cv score 10 fold  \
# 0       0.724490  [0.5277777777777778, 0.6111111111111112, 0.416...
# 1       0.775510  [0.5833333333333334, 0.6388888888888888, 0.444...
# 2       0.785714  [0.6111111111111112, 0.6666666666666666, 0.472...
# 3       0.785714  [0.6111111111111112, 0.6666666666666666, 0.472...
# 4       0.632653  [0.5, 0.6111111111111112, 0.3888888888888889, ...
# 5       0.775510  [0.5833333333333334, 0.6666666666666666, 0.444...
# 6       0.785714  [0.6111111111111112, 0.6666666666666666, 0.472...
# 7       0.785714  [0.6111111111111112, 0.6666666666666666, 0.472...
#
#                                     cv score 50 fold  cv mean score 10  \
# 0  [0.375, 0.375, 0.625, 0.5, 0.75, 0.375, 0.625,...          0.511111
# 1  [0.625, 0.75, 0.625, 0.375, 0.75, 0.75, 0.5, 0...          0.555556
# 2  [0.625, 0.75, 0.625, 0.375, 0.75, 0.75, 0.625,...          0.541667
# 3  [0.625, 0.75, 0.625, 0.375, 0.75, 0.75, 0.625,...          0.544444
# 4  [0.5, 0.375, 0.625, 0.75, 0.625, 0.625, 0.625,...          0.525000
# 5  [0.625, 0.75, 0.625, 0.375, 0.75, 0.75, 0.5, 0...          0.558333
# 6  [0.625, 0.75, 0.625, 0.375, 0.75, 0.75, 0.625,...          0.541667
# 7  [0.625, 0.75, 0.625, 0.375, 0.75, 0.75, 0.625,...          0.541667
#
#    cv mean score 50
# 0          0.541071
# 1          0.581786
# 2          0.561786
# 3          0.561786
# 4          0.539643
# 5          0.578929
# 6          0.561786
# 7          0.558929

# %%
# --> none sag & RR sag with accuracy 81.3/82.2
# sourceFile = open('answer.csv', 'w')
# print('82.2', file = sourceFile)
# sourceFile.close()

# %%
answe=pd.read_csv('answers.csv')
answe
# Out:
#            class4         p
# 0   0    nonevent  0.154972
# 1   1          Ia  0.233739
# 2   2          Ib  0.410445
# 3   3          II  0.545141
# 4   4    nonevent  0.131124
# 5   ..        ...       ...
# 6   960  nonevent  0.328844
# 7   961  nonevent  0.066268
# 8   962        Ib  0.386109
# 9   963        Ib  0.260775
# 10  964  nonevent  0.133526
# 11   [965 rows x 2 columns]

# %%
npf_hid=pd.read_csv('npf_test_hidden.csv')
npf_hid = npf_hid.drop("partlybad",axis=1)
npf_hid = npf_hid.drop("date",axis=1)
npf_hid = npf_hid.drop("class4",axis=1)

# %%
npf_hid = npf_hid.drop("id",axis=1)

# %%
npf_hid
# Out:
#      CO2168.mean  CO2168.std  CO2336.mean  CO2336.std  CO242.mean  CO242.std  \
# 0     376.610169    0.526617   376.660339    0.500203  376.934655   0.564360
# 1     390.624932    0.453585   390.580694    0.455308  391.000685   0.505836
# 2     375.280258    1.249087   375.479806    1.241525  375.624129   1.423506
# 3     382.642176    3.222805   382.890412    3.026140  383.136941   3.466259
# 4     381.492971    4.386929   381.608000    4.333558  382.177784   4.491875
# ..           ...         ...          ...         ...         ...        ...
# 960   387.945654    8.594281   387.195208    6.395089  390.564398  12.503105
# 961   381.204386    0.172730   381.193333    0.174513  381.289123   0.174594
# 962   383.915986    2.407693   383.944965    2.349077  384.052183   2.456562
# 963   379.521641    1.199564   379.525194    1.147027  379.778906   1.257693
# 964   388.033466   13.690201   387.962273   12.878477  390.622971  15.321954
#
#      CO2504.mean  CO2504.std   Glob.mean    Glob.std  ...  T672.mean  \
# 0     376.634746    0.471236   37.115592   24.180794  ...  -2.851967
# 1     390.487945    0.481292   69.134531   59.895057  ... -18.646384
# 2     375.571474    1.200556  276.485371  201.722672  ...   3.485822
# 3     382.937706    2.837540  308.904304  287.444652  ...   6.933127
# 4     381.588857    4.263299  111.456879  104.807009  ...  11.941411
# ..           ...         ...         ...         ...  ...        ...
# 960   386.868542    5.561891  225.755653  245.560692  ...  13.846229
# 961   381.174737    0.179355   12.633440    6.528276  ...  -5.539621
# 962   383.862958    2.212343  312.786155  206.675746  ...   6.970141
# 963   379.473203    1.078942  315.506008  166.933151  ...   1.643628
# 964   387.520114   11.730093  283.848987  224.744206  ...  22.733969
#
#      T672.std   T84.mean   T84.std  UV_A.mean   UV_A.std  UV_B.mean  UV_B.std  \
# 0    0.156421  -2.356066  0.174219   2.374336   1.318965   0.040709  0.024647
# 1    0.448865 -18.030984  0.478829   3.850439   2.056031   0.103446  0.060432
# 2    1.526998   4.649689  1.978654  15.498463  11.001410   0.557332  0.494026
# 3    3.737176   7.657725  3.823123  16.909366  13.924594   0.646806  0.602040
# 4    2.195680  12.570801  2.458619   7.596930   6.722838   0.275559  0.312076
# ..        ...        ...       ...        ...        ...        ...       ...
# 960  1.908796  14.671475  2.278146  14.888953  13.891135   0.724499  0.741484
# 961  0.189930  -5.018333  0.192347   1.208696   0.588515   0.022685  0.011805
# 962  2.270736   7.698230  2.916700  16.280512  10.828638   0.572551  0.464658
# 963  2.549993   2.697919  2.916053  15.014020   8.972121   0.546366  0.416863
# 964  2.191116  23.527735  2.663090  17.161429  12.328885   0.831893  0.721734
#
#       CS.mean    CS.std
# 0    0.000644  0.000119
# 1    0.003707  0.000115
# 2    0.001637  0.000428
# 3    0.002480  0.000510
# 4    0.009429  0.004438
# ..        ...       ...
# 960  0.002978  0.000775
# 961  0.002506  0.000101
# 962  0.006474  0.000857
# 963  0.000829  0.000227
# 964  0.007750  0.001455
#
# [965 rows x 100 columns]

# %%
answers=model_lr_none_sag.predict(npf_hid) 

answers
# Out:
# array(['nonevent', 'Ia', 'Ib', 'II', 'nonevent', 'II', 'nonevent',
#        'nonevent', 'II', 'nonevent', 'nonevent', 'nonevent', 'nonevent',
#        'nonevent', 'II', 'nonevent', 'nonevent', 'nonevent', 'Ib',
#        'nonevent', 'nonevent', 'nonevent', 'nonevent', 'nonevent',
#        'nonevent', 'II', 'nonevent', 'II', 'nonevent', 'nonevent',
#        'nonevent', 'Ib', 'nonevent', 'nonevent', 'II', 'II', 'II',
#        'nonevent', 'Ia', 'nonevent', 'nonevent', 'Ib', 'II', 'nonevent',
#        'II', 'nonevent', 'nonevent', 'II', 'Ib', 'nonevent', 'Ib',
#        'nonevent', 'nonevent', 'II', 'nonevent', 'nonevent', 'Ib',
#        'nonevent', 'II', 'nonevent', 'nonevent', 'II', 'nonevent',
#        'nonevent', 'II', 'nonevent', 'nonevent', 'II', 'II', 'II', 'II',
#        'Ib', 'nonevent', 'nonevent', 'nonevent', 'II', 'nonevent',
#        'nonevent', 'nonevent', 'nonevent', 'II', 'nonevent', 'nonevent',
#        'nonevent', 'Ib', 'II', 'nonevent', 'nonevent', 'nonevent', 'Ib',
#        'nonevent', 'nonevent', 'nonevent', 'Ib', 'II', 'nonevent',
#        'nonevent', 'II', 'nonevent', 'Ib', 'nonevent', 'nonevent', 'Ib',
#        'nonevent', 'II', 'nonevent', 'II', 'nonevent', 'Ib', 'nonevent',
#        'nonevent', 'nonevent', 'Ia', 'nonevent', 'nonevent', 'II',
#        'nonevent', 'Ib', 'Ib', 'nonevent', 'nonevent', 'Ib', 'nonevent',
#        'Ib', 'nonevent', 'nonevent', 'II', 'II', 'nonevent', 'nonevent',
#        'nonevent', 'nonevent', 'nonevent', 'nonevent', 'II', 'Ib',
#        'nonevent', 'Ib', 'nonevent', 'Ib', 'nonevent', 'II', 'Ib',
#        'nonevent', 'nonevent', 'nonevent', 'nonevent', 'nonevent', 'II',
#        'Ib', 'II', 'nonevent', 'nonevent', 'nonevent', 'nonevent', 'II',
#        'nonevent', 'Ib', 'II', 'II', 'nonevent', 'nonevent', 'nonevent',
#        'nonevent', 'nonevent', 'II', 'II', 'nonevent', 'nonevent',
#        'nonevent', 'nonevent', 'nonevent', 'nonevent', 'Ib', 'nonevent',
#        'nonevent', 'II', 'II', 'II', 'Ib', 'II', 'Ia', 'nonevent',
#        'nonevent', 'nonevent', 'II', 'II', 'nonevent', 'II', 'nonevent',
#        'nonevent', 'nonevent', 'II', 'II', 'nonevent', 'nonevent', 'II',
#        'nonevent', 'nonevent', 'nonevent', 'Ib', 'Ib', 'nonevent',
#        'nonevent', 'Ia', 'II', 'Ib', 'II', 'nonevent', 'II', 'nonevent',
#        'nonevent', 'nonevent', 'nonevent', 'II', 'Ib', 'Ib', 'nonevent',
#        'Ib', 'Ia', 'nonevent', 'II', 'nonevent', 'Ib', 'Ib', 'II',
#        'nonevent', 'II', 'nonevent', 'nonevent', 'nonevent', 'nonevent',
#        'nonevent', 'nonevent', 'nonevent', 'nonevent', 'nonevent', 'II',
#        'II', 'II', 'II', 'nonevent', 'nonevent', 'nonevent', 'Ib', 'II',
#        'nonevent', 'nonevent', 'nonevent', 'Ib', 'nonevent', 'nonevent',
#        'II', 'II', 'Ia', 'nonevent', 'nonevent', 'nonevent', 'nonevent',
#        'nonevent', 'Ib', 'nonevent', 'II', 'nonevent', 'II', 'nonevent',
#        'nonevent', 'II', 'nonevent', 'nonevent', 'nonevent', 'nonevent',
#        'nonevent', 'II', 'nonevent', 'II', 'II', 'nonevent', 'nonevent',
#        'II', 'II', 'II', 'nonevent', 'Ib', 'nonevent', 'nonevent',
#        'nonevent', 'Ib', 'nonevent', 'II', 'Ib', 'nonevent', 'II',
#        'nonevent', 'nonevent', 'nonevent', 'nonevent', 'Ia', 'nonevent',
#        'nonevent', 'nonevent', 'nonevent', 'II', 'II', 'nonevent', 'II',
#        'Ib', 'Ib', 'nonevent', 'II', 'II', 'II', 'nonevent', 'nonevent',
#        'II', 'Ib', 'Ia', 'Ib', 'nonevent', 'Ia', 'nonevent', 'nonevent',
#        'nonevent', 'nonevent', 'nonevent', 'nonevent', 'nonevent',
#        'nonevent', 'nonevent', 'nonevent', 'nonevent', 'nonevent',
#        'nonevent', 'II', 'Ib', 'II', 'nonevent', 'nonevent', 'nonevent',
#        'nonevent', 'II', 'II', 'nonevent', 'nonevent', 'II', 'II',
#        'nonevent', 'nonevent', 'Ib', 'nonevent', 'II', 'Ib', 'nonevent',
#        'nonevent', 'Ib', 'II', 'II', 'II', 'Ia', 'II', 'Ib', 'Ib',
#        'nonevent', 'nonevent', 'Ib', 'nonevent', 'nonevent', 'Ib',
#        'nonevent', 'nonevent', 'nonevent', 'nonevent', 'II', 'Ib', 'Ib',
#        'Ib', 'nonevent', 'nonevent', 'nonevent', 'nonevent', 'Ib', 'II',
#        'Ib', 'nonevent', 'nonevent', 'nonevent', 'nonevent', 'II', 'II',
#        'nonevent', 'nonevent', 'II', 'nonevent', 'nonevent', 'II',
#        'nonevent', 'nonevent', 'nonevent', 'nonevent', 'nonevent', 'II',
#        'II', 'nonevent', 'II', 'nonevent', 'II', 'nonevent', 'Ia', 'Ib',
#        'Ia', 'II', 'nonevent', 'nonevent', 'nonevent', 'nonevent', 'II',
#        'II', 'II', 'nonevent', 'nonevent', 'nonevent', 'Ib', 'II',
#        'nonevent', 'nonevent', 'II', 'nonevent', 'II', 'II', 'nonevent',
#        'nonevent', 'II', 'nonevent', 'nonevent', 'nonevent', 'II',
#        'nonevent', 'II', 'II', 'nonevent', 'II', 'Ib', 'nonevent', 'Ib',
#        'Ia', 'nonevent', 'nonevent', 'nonevent', 'II', 'nonevent', 'Ib',
#        'nonevent', 'II', 'nonevent', 'Ib', 'nonevent', 'II', 'nonevent',
#        'Ib', 'nonevent', 'II', 'II', 'nonevent', 'nonevent', 'II',
#        'nonevent', 'nonevent', 'II', 'Ib', 'II', 'nonevent', 'nonevent',
#        'nonevent', 'nonevent', 'nonevent', 'II', 'II', 'nonevent',
#        'nonevent', 'nonevent', 'nonevent', 'nonevent', 'Ib', 'nonevent',
#        'nonevent', 'nonevent', 'Ib', 'II', 'II', 'nonevent', 'nonevent',
#        'nonevent', 'II', 'Ib', 'Ia', 'II', 'Ib', 'Ib', 'nonevent',
#        'nonevent', 'Ia', 'II', 'nonevent', 'nonevent', 'nonevent',
#        'nonevent', 'nonevent', 'Ib', 'Ib', 'nonevent', 'II', 'nonevent',
#        'nonevent', 'nonevent', 'nonevent', 'nonevent', 'nonevent',
#        'nonevent', 'nonevent', 'nonevent', 'nonevent', 'nonevent',
#        'nonevent', 'nonevent', 'nonevent', 'nonevent', 'nonevent',
#        'nonevent', 'Ib', 'nonevent', 'II', 'nonevent', 'nonevent',
#        'nonevent', 'nonevent', 'nonevent', 'nonevent', 'II', 'nonevent',
#        'II', 'nonevent', 'nonevent', 'nonevent', 'Ib', 'nonevent', 'Ib',
#        'nonevent', 'II', 'nonevent', 'nonevent', 'nonevent', 'II', 'Ib',
#        'Ib', 'nonevent', 'nonevent', 'Ib', 'nonevent', 'nonevent', 'Ib',
#        'nonevent', 'Ia', 'II', 'II', 'II', 'nonevent', 'II', 'nonevent',
#        'nonevent', 'nonevent', 'nonevent', 'nonevent', 'nonevent', 'II',
#        'Ia', 'nonevent', 'II', 'nonevent', 'Ib', 'Ia', 'nonevent',
#        'nonevent', 'nonevent', 'nonevent', 'nonevent', 'nonevent',
#        'nonevent', 'nonevent', 'nonevent', 'II', 'nonevent', 'Ib',
#        'nonevent', 'nonevent', 'Ib', 'Ia', 'nonevent', 'nonevent',
#        'nonevent', 'nonevent', 'nonevent', 'nonevent', 'II', 'nonevent',
#        'Ib', 'nonevent', 'nonevent', 'II', 'nonevent', 'nonevent', 'II',
#        'nonevent', 'nonevent', 'nonevent', 'II', 'Ia', 'Ib', 'nonevent',
#        'nonevent', 'nonevent', 'II', 'II', 'nonevent', 'nonevent',
#        'nonevent', 'II', 'nonevent', 'II', 'nonevent', 'nonevent',
#        'nonevent', 'II', 'nonevent', 'II', 'nonevent', 'nonevent',
#        'nonevent', 'II', 'Ib', 'nonevent', 'Ia', 'nonevent', 'Ib',
#        'nonevent', 'II', 'nonevent', 'II', 'II', 'nonevent', 'Ib',
#        'nonevent', 'nonevent', 'nonevent', 'Ib', 'nonevent', 'nonevent',
#        'II', 'Ib', 'nonevent', 'II', 'nonevent', 'II', 'II', 'nonevent',
#        'nonevent', 'II', 'nonevent', 'Ia', 'nonevent', 'nonevent',
#        'nonevent', 'nonevent', 'Ib', 'nonevent', 'nonevent', 'nonevent',
#        'nonevent', 'nonevent', 'nonevent', 'nonevent', 'Ia', 'Ib', 'Ib',
#        'nonevent', 'nonevent', 'nonevent', 'II', 'Ib', 'nonevent',
#        'nonevent', 'nonevent', 'nonevent', 'Ia', 'II', 'Ib', 'nonevent',
#        'nonevent', 'II', 'II', 'nonevent', 'II', 'II', 'II', 'II', 'II',
#        'nonevent', 'II', 'Ib', 'nonevent', 'nonevent', 'Ib', 'Ib',
#        'nonevent', 'Ib', 'Ib', 'nonevent', 'II', 'Ib', 'nonevent',
#        'nonevent', 'nonevent', 'nonevent', 'Ib', 'II', 'II', 'nonevent',
#        'nonevent', 'nonevent', 'nonevent', 'nonevent', 'nonevent', 'Ib',
#        'Ia', 'nonevent', 'II', 'nonevent', 'nonevent', 'nonevent', 'II',
#        'nonevent', 'II', 'nonevent', 'Ib', 'Ib', 'nonevent', 'nonevent',
#        'II', 'nonevent', 'nonevent', 'nonevent', 'nonevent', 'nonevent',
#        'nonevent', 'nonevent', 'nonevent', 'nonevent', 'II', 'II',
#        'nonevent', 'nonevent', 'nonevent', 'nonevent', 'nonevent', 'Ib',
#        'nonevent', 'nonevent', 'II', 'II', 'nonevent', 'nonevent',
#        'nonevent', 'II', 'nonevent', 'II', 'nonevent', 'II', 'II',
#        'nonevent', 'nonevent', 'nonevent', 'nonevent', 'nonevent',
#        'nonevent', 'Ib', 'nonevent', 'II', 'nonevent', 'nonevent',
#        'nonevent', 'II', 'nonevent', 'nonevent', 'nonevent', 'Ib', 'Ib',
#        'II', 'Ib', 'nonevent', 'II', 'nonevent', 'nonevent', 'nonevent',
#        'II', 'nonevent', 'Ib', 'Ib', 'II', 'nonevent', 'Ia', 'II',
#        'nonevent', 'nonevent', 'II', 'nonevent', 'II', 'II', 'nonevent',
#        'nonevent', 'nonevent', 'Ib', 'nonevent', 'nonevent', 'nonevent',
#        'Ib', 'nonevent', 'nonevent', 'II', 'nonevent', 'nonevent',
#        'nonevent', 'nonevent', 'Ib', 'nonevent', 'II', 'Ia', 'nonevent',
#        'II', 'nonevent', 'nonevent', 'Ib', 'II', 'nonevent', 'nonevent',
#        'nonevent', 'II', 'nonevent', 'nonevent', 'nonevent', 'nonevent',
#        'nonevent', 'nonevent', 'Ib', 'II', 'II', 'Ib', 'nonevent',
#        'nonevent', 'nonevent', 'nonevent', 'Ib', 'Ib', 'II', 'nonevent',
#        'nonevent', 'nonevent', 'nonevent', 'II', 'Ib', 'II', 'Ib',
#        'nonevent', 'nonevent', 'nonevent', 'nonevent', 'II', 'nonevent',
#        'II', 'nonevent', 'Ib', 'nonevent', 'nonevent', 'Ia', 'nonevent',
#        'nonevent', 'nonevent', 'nonevent', 'nonevent', 'nonevent', 'II',
#        'nonevent', 'Ib', 'nonevent', 'nonevent', 'nonevent', 'nonevent',
#        'II', 'nonevent', 'II', 'nonevent', 'II', 'nonevent', 'Ib',
#        'nonevent', 'Ib', 'Ia', 'Ia', 'nonevent', 'nonevent', 'Ib',
#        'nonevent', 'II', 'Ib', 'nonevent', 'nonevent', 'Ib', 'nonevent',
#        'nonevent', 'nonevent', 'nonevent', 'nonevent', 'nonevent', 'Ib',
#        'nonevent', 'nonevent', 'Ib', 'nonevent', 'II', 'nonevent',
#        'nonevent', 'II', 'Ib', 'nonevent', 'II', 'II', 'II', 'II',
#        'nonevent', 'II', 'nonevent', 'nonevent', 'II', 'nonevent',
#        'nonevent', 'nonevent', 'II', 'nonevent', 'nonevent', 'II',
#        'nonevent', 'nonevent', 'II', 'nonevent', 'Ib', 'II', 'II',
#        'nonevent', 'II', 'nonevent', 'nonevent', 'Ib', 'nonevent',
#        'nonevent', 'Ib', 'Ib', 'nonevent'], dtype=object)

# %%
p_class4=model.predict_proba(npf_hid)
p=p_class4[:, 0]
# proba=pd.Series()
# for i in p_class4:
# p=p_class4[:,0]

# %%
res=pd.DataFrame()
res['class4']=answers
res['p']=p
# Out:
#       class4         p
# 0   nonevent  0.154972
# 1         Ia  0.233739
# 2         Ib  0.410445
# 3         II  0.545141
# 4   nonevent  0.131124
# 5         II  0.542061
# 6   nonevent  0.042579
# 7   nonevent  0.033789
# 8         II  0.514498
# 9   nonevent  0.382616
# 10  nonevent  0.116935
# 11  nonevent  0.369980
# 12  nonevent  0.080148
# 13  nonevent  0.123994
# 14        II  0.451598
# 15  nonevent  0.051449
# 16  nonevent  0.242955
# 17  nonevent  0.268896
# 18        Ib  0.356474
# 19  nonevent  0.072214

# %%
sourceFile = open('answer.csv', 'w')
print(res, file = sourceFile)
sourceFile.close()
